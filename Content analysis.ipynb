# %%
import pandas as pd
from pathlib import Path
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.decomposition import PCA

from tqdm.notebook import tqdm
import time
pd.options.display.max_rows = 100
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
file_path = Path("./Recipe generator/data/recipes.csv")
df1 = pd.read_csv(file_path)

# %%
#dataset cleanup
df1.dropna(subset=['RecipeId', 'AggregatedRating'], axis=0, inplace=True)
df2=df1["AggregatedRating"].value_counts()
df2
# Out:
# AggregatedRating
# 5.0    174516
# 4.0     42829
# 4.5     34330
# 3.0      9166
# 3.5      3978
# 2.0      2049
# 1.0      1677
# 2.5       673
# 1.5        76
# Name: count, dtype: int64

# %%
#sample "sample_size" recipes from each rating
import pandas as pd
import random, math
sample_size=1676

df_trunc=df1.iloc[[0]]
df_trunc.drop(index=0,inplace=True)
for j in tqdm(df2.index):
    if df2[j]>sample_size:
        # for k in tqdm(range(0,df2[df2>sample_size].min())):
        for k in tqdm(range(0,sample_size)):
            df_trunc = pd.concat([df_trunc, df1[df1["AggregatedRating"]==j].reset_index().iloc[[math.floor(random.random()*df2[j])]]])
df=df_trunc
df_trunc["AggregatedRating"].value_counts()
# Out:
# /var/folders/vf/vmk7hfw95j1f6p8wn00dpk3m0000gn/T/ipykernel_82854/2934695877.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trunc.drop(index=0,inplace=True)
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
# AggregatedRating
# 5.0    1676
# 4.0    1676
# 4.5    1676
# 3.0    1676
# 3.5    1676
# 2.0    1676
# 1.0    1676
# Name: count, dtype: int64

# %%
df_combined=df[["AggregatedRating", "Calories", "FatContent", "SaturatedFatContent", "CholesterolContent", "SodiumContent", "CarbohydrateContent", "FiberContent", "SugarContent", "ProteinContent"]]

df_combined.dropna(inplace=True)
df_combined
# Out:
# /var/folders/vf/vmk7hfw95j1f6p8wn00dpk3m0000gn/T/ipykernel_82854/2468353610.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined.dropna(inplace=True)
#         AggregatedRating  Calories  FatContent  SaturatedFatContent  \
# 145457               5.0     161.3         0.0                  0.0
# 4998                 5.0       6.1         0.0                  0.0
# 14152                5.0     429.1        13.6                  2.7
# 49729                5.0     461.7        21.2                  9.8
# 93074                5.0     180.3         8.0                  1.5
# ...                  ...       ...         ...                  ...
# 84                   1.0     307.4        11.2                  1.5
# 1540                 1.0     238.7        18.0                  9.9
# 1526                 1.0     191.8        12.5                  4.9
# 586                  1.0      90.5         2.9                  0.5
# 1599                 1.0     378.5        13.2                  3.4
#
#         CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 145457                 0.0          103.9                 21.8           0.0
# 4998                   0.0            0.0                  1.1           0.1
# 14152                 58.8          546.5                 50.2           9.0
# 49729                 17.1          139.5                 72.1           3.9
# 93074                  7.2          355.3                 19.8           2.2
# ...                    ...            ...                  ...           ...
# 84                     0.5         1567.3                 45.5           2.1
# 1540                  32.5          109.4                 21.1           1.1
# 1526                  19.9          293.7                 13.4           5.9
# 586                   33.1          881.9                  6.8           1.1
# 1599                  78.2          881.1                 34.5           6.0
#
#         SugarContent  ProteinContent
# 145457          19.2             1.7
# 4998             1.0             0.0
# 14152            3.5            26.5
# 49729           58.6             5.4
# 93074            6.6             7.8
# ...              ...             ...
# 84               3.2             6.6
# 1540            19.4             1.4
# 1526             4.4            10.6
# 586              2.8            10.5
# 1599             5.7            38.0
#
# [11732 rows x 10 columns]

# %%
df_combined
# Out:
#         AggregatedRating  Calories  FatContent  SaturatedFatContent  \
# 145457               5.0     161.3         0.0                  0.0
# 4998                 5.0       6.1         0.0                  0.0
# 14152                5.0     429.1        13.6                  2.7
# 49729                5.0     461.7        21.2                  9.8
# 93074                5.0     180.3         8.0                  1.5
# ...                  ...       ...         ...                  ...
# 84                   1.0     307.4        11.2                  1.5
# 1540                 1.0     238.7        18.0                  9.9
# 1526                 1.0     191.8        12.5                  4.9
# 586                  1.0      90.5         2.9                  0.5
# 1599                 1.0     378.5        13.2                  3.4
#
#         CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 145457                 0.0          103.9                 21.8           0.0
# 4998                   0.0            0.0                  1.1           0.1
# 14152                 58.8          546.5                 50.2           9.0
# 49729                 17.1          139.5                 72.1           3.9
# 93074                  7.2          355.3                 19.8           2.2
# ...                    ...            ...                  ...           ...
# 84                     0.5         1567.3                 45.5           2.1
# 1540                  32.5          109.4                 21.1           1.1
# 1526                  19.9          293.7                 13.4           5.9
# 586                   33.1          881.9                  6.8           1.1
# 1599                  78.2          881.1                 34.5           6.0
#
#         SugarContent  ProteinContent
# 145457          19.2             1.7
# 4998             1.0             0.0
# 14152            3.5            26.5
# 49729           58.6             5.4
# 93074            6.6             7.8
# ...              ...             ...
# 84               3.2             6.6
# 1540            19.4             1.4
# 1526             4.4            10.6
# 586              2.8            10.5
# 1599             5.7            38.0
#
# [11732 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
X=df_combined.drop(columns='AggregatedRating')
y=df_combined['AggregatedRating']

X_scaled=StandardScaler().fit_transform(df_combined[["Calories", "FatContent", "SaturatedFatContent", "CholesterolContent", "SodiumContent", "CarbohydrateContent", "FiberContent", "SugarContent", "ProteinContent"]])
X_scaled=pd.DataFrame(X_scaled, columns=["Calories", "FatContent", "SaturatedFatContent", "CholesterolContent", "SodiumContent", "CarbohydrateContent", "FiberContent", "SugarContent", "ProteinContent"])

model = LinearRegression()
model.fit(X_scaled, y)
print(f"Model's slope: {model.coef_}")
print(f"Model's y-intercept: {model.intercept_}")
print(f"Model's formula: y = {model.intercept_} + {model.coef_[0]}X")

# Make predictions using the X set
predicted_y_values = pd.DataFrame(model.predict(X_scaled), columns=['predicted values'])
# Create a copy of the original data
df_rating_predicted = pd.concat([df_combined['AggregatedRating'].reset_index(),predicted_y_values],axis=1)

# Display sample data
df_rating_predicted.head()
pd.DataFrame([model.coef_], columns=["Calories", "FatContent", "SaturatedFatContent", "CholesterolContent", "SodiumContent", "CarbohydrateContent", "FiberContent", "SugarContent", "ProteinContent"]).T.rename(columns={0: "slope"}).sort_values('slope', ascending=False)
# Out:
# Model's slope: [ 0.22721062 -0.20122089  0.06571748 -0.02127674  0.03260574 -0.20290241
#   0.01139929  0.01785751  0.01803982]
# Model's y-intercept: 3.2857142857142856
# Model's formula: y = 3.2857142857142856 + 0.2272106160135901X
#                         slope
# Calories             0.227211
# SaturatedFatContent  0.065717
# SodiumContent        0.032606
# ProteinContent       0.018040
# SugarContent         0.017858
# FiberContent         0.011399
# CholesterolContent  -0.021277
# FatContent          -0.201221
# CarbohydrateContent -0.202902

# %%
df_rating_predicted['AggregatedRating'].sort_values(ascending=False).value_counts().index
# Out:
# Index([5.0, 4.5, 4.0, 3.5, 3.0, 2.0, 1.0], dtype='float64', name='AggregatedRating')

# %%
positions
# Out:
# [5.0, 4.0, 4.5, 3.0, 3.5, 2.0, 1.0, 2.5, 1.5]

# %%
from numpy import random
import matplotlib.pyplot as plt
boxes=[]
positions=[]
for rating in df_rating_predicted['AggregatedRating'].sort_values(ascending=False).value_counts().index:
    boxes.append(df_rating_predicted[df_rating_predicted['AggregatedRating']==rating]['predicted values'])
    positions.append(rating)

# %%
#COPY for calories

from numpy import random
import matplotlib.pyplot as plt
boxes=[]
positions=[]
for rating in df_combined['AggregatedRating'].sort_values(ascending=False).value_counts().index:
    boxes.append(df_combined[df_combined['AggregatedRating']==rating]['Calories'])
    positions.append(rating)

plt.violinplot(boxes, positions=positions, widths=.3)
plt.boxplot(boxes, positions=positions, widths=.3, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_combined['AggregatedRating']+0.2*random.rand(len(df_combined['AggregatedRating']),1).ravel()-.1,
            df_combined['Calories'],marker='o',s=.01,c='r')
plt.xlabel("Rating")
plt.ylabel("Calories")
plt.ylim(-100,1250)
plt.title('Rating dependece on calories')
plt.show()

# %%
#COPY for FatContent

from numpy import random
import matplotlib.pyplot as plt
boxes=[]
positions=[]
for rating in df_combined['AggregatedRating'].sort_values(ascending=False).value_counts().index:
    boxes.append(df_combined[df_combined['AggregatedRating']==rating]['FatContent'])
    positions.append(rating)

plt.violinplot(boxes, positions=positions, widths=.3)
plt.boxplot(boxes, positions=positions, widths=.3, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_combined['AggregatedRating']+0.2*random.rand(len(df_combined['AggregatedRating']),1).ravel()-.1,
            df_combined['FatContent'],marker='o',s=.01,c='r')
plt.xlabel("Rating")
plt.ylabel("FatContent")
plt.ylim(-5,65)
plt.title('Rating dependece on FatContent')
plt.show()

# %%
#COPY for SodiumContent

from numpy import random
import matplotlib.pyplot as plt
boxes=[]
positions=[]
for rating in df_combined['AggregatedRating'].sort_values(ascending=False).value_counts().index:
    boxes.append(df_combined[df_combined['AggregatedRating']==rating]['SodiumContent'])
    positions.append(rating)

plt.violinplot(boxes, positions=positions, widths=.3)
plt.boxplot(boxes, positions=positions, widths=.3, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_combined['AggregatedRating']+0.2*random.rand(len(df_combined['AggregatedRating']),1).ravel()-.1,
            df_combined['SodiumContent'],marker='o',s=.01,c='r')
plt.xlabel("Rating")
plt.ylabel("SodiumContent")
plt.ylim(-50,2000)
plt.title('Rating dependece on SodiumContent')
plt.show()

# %%
#COPY for CarbohydrateContent

from numpy import random
import matplotlib.pyplot as plt
boxes=[]
positions=[]
for rating in df_combined['AggregatedRating'].sort_values(ascending=False).value_counts().index:
    boxes.append(df_combined[df_combined['AggregatedRating']==rating]['CarbohydrateContent'])
    positions.append(rating)

plt.violinplot(boxes, positions=positions, widths=.3)
plt.boxplot(boxes, positions=positions, widths=.3, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_combined['AggregatedRating']+0.2*random.rand(len(df_combined['AggregatedRating']),1).ravel()-.1,
            df_combined['CarbohydrateContent'],marker='o',s=.01,c='r')
plt.xlabel("Rating")
plt.ylabel("CarbohydrateContent")
plt.ylim(-10,125)
plt.title('Rating dependece on CarbohydrateContent')
plt.show()

# %%
#COPY for FiberContent

from numpy import random
import matplotlib.pyplot as plt
boxes=[]
positions=[]
for rating in df_combined['AggregatedRating'].sort_values(ascending=False).value_counts().index:
    boxes.append(df_combined[df_combined['AggregatedRating']==rating]['FiberContent'])
    positions.append(rating)

plt.violinplot(boxes, positions=positions, widths=.3)
plt.boxplot(boxes, positions=positions, widths=.3, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_combined['AggregatedRating']+0.2*random.rand(len(df_combined['AggregatedRating']),1).ravel()-.1,
            df_combined['FiberContent'],marker='o',s=.01,c='r')
plt.xlabel("Rating")
plt.ylabel("FiberContent")
plt.ylim(-1,12)
plt.title('Rating dependece on FiberContent')
plt.show()

# %%
#COPY for SugarContent

from numpy import random
import matplotlib.pyplot as plt
boxes=[]
positions=[]
for rating in df_combined['AggregatedRating'].sort_values(ascending=False).value_counts().index:
    boxes.append(df_combined[df_combined['AggregatedRating']==rating]['SugarContent'])
    positions.append(rating)

plt.violinplot(boxes, positions=positions, widths=.3)
plt.boxplot(boxes, positions=positions, widths=.3, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_combined['AggregatedRating']+0.2*random.rand(len(df_combined['AggregatedRating']),1).ravel()-.1,
            df_combined['SugarContent'],marker='o',s=.01,c='r')
plt.xlabel("Rating")
plt.ylabel("SugarContent")
plt.ylim(-5,55)
plt.title('Rating dependece on SugarContent')
plt.show()

# %%
#COPY for ProteinContent

from numpy import random
import matplotlib.pyplot as plt
boxes=[]
positions=[]
for rating in df_combined['AggregatedRating'].sort_values(ascending=False).value_counts().index:
    boxes.append(df_combined[df_combined['AggregatedRating']==rating]['ProteinContent'])
    positions.append(rating)

plt.violinplot(boxes, positions=positions, widths=.3)
plt.boxplot(boxes, positions=positions, widths=.3, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_combined['AggregatedRating']+0.2*random.rand(len(df_combined['AggregatedRating']),1).ravel()-.1,
            df_combined['ProteinContent'],marker='o',s=.01,c='r')
plt.xlabel("Rating")
plt.ylabel("ProteinContent")
plt.ylim(-10,100)
plt.title('Rating dependece on ProteinContent')
plt.show()

# %%
plt.boxplot(boxes, positions=positions, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_rating_predicted['AggregatedRating']+0.2*random.rand(len(df_rating_predicted['AggregatedRating']),1).ravel()-.1,
            df_rating_predicted['predicted values'],marker='o',s=.01,c='r')
plt.show()

# %%
plt.boxplot(df_combined['AggregatedRating'],
            df_combined['Calories'])

# %%
import seaborn as sns
plt.figure(figsize=(14,3))
plt.boxplot(boxes,labels=labels, showbox=False, flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.violinplot(boxes, widths=.9)
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.ylabel('Rating')
plt.title('World cuisine rating')
plt.ylim(0,5.1)
plt.show()

# %%
# pd.DataFrame(df1[df1["ReviewCount"]>100]["ReviewCount"].value_counts()).sort_values(by='ReviewCount')

# %%
# df=df.drop(df.index[100:])
# df = df1[df1["ReviewCount"]>20]
# len(df)

# %%
# pd.DataFrame(df1[df1["AggregatedRating"]>100]["ReviewCount"].value_counts()).sort_values(by='ReviewCount')
df2=df1["AggregatedRating"].value_counts()
df2
# df1["AggregatedRating"]=
# Out:
# AggregatedRating
# 5.0    174516
# 4.0     42829
# 4.5     34330
# 3.0      9166
# 3.5      3978
# 2.0      2049
# 1.0      1677
# 2.5       673
# 1.5        76
# Name: count, dtype: int64

# %%
df2
# Out:
# AggregatedRating
# 5.0    174516
# 4.0     42829
# 4.5     34330
# 3.0      9166
# 3.5      3978
# 2.0      2049
# 1.0      1677
# 2.5       673
# 1.5        76
# Name: count, dtype: int64

# %%
#sample "sample_size" recipes from each rating
import pandas as pd
import random, math
sample_size=1676

df_trunc=df1.iloc[[0]]
df_trunc.drop(index=0,inplace=True)
for j in tqdm(df2.index):
    if df2[j]>sample_size:
        # for k in tqdm(range(0,df2[df2>sample_size].min())):
        for k in tqdm(range(0,sample_size)):
            df_trunc = pd.concat([df_trunc, df1[df1["AggregatedRating"]==j].reset_index().iloc[[math.floor(random.random()*df2[j])]]])
# Out:
# /var/folders/vf/vmk7hfw95j1f6p8wn00dpk3m0000gn/T/ipykernel_3644/3658878438.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trunc.drop(index=0,inplace=True)
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 0/1676 [00:00<?, ?it/s]

# %%
df=df_trunc
df_trunc["AggregatedRating"].value_counts()
# Out:
# AggregatedRating
# 5.0    1676
# 4.0    1676
# 4.5    1676
# 3.0    1676
# 3.5    1676
# 2.0    1676
# 1.0    1676
# Name: count, dtype: int64

# %%
ingredients=df["RecipeIngredientParts"]
keywords=df["Keywords"]

# %%
#splitting ingredients to separate columns
ingredients = ingredients.str.replace(" ", "\"")
temp =ingredients.str.split("\"",expand=True)
dummies=pd.get_dummies(temp,dtype=int)
dummies.columns=dummies.columns.str.lower()
s=dummies.columns.str.lstrip('0123456789_').str.lower()
s=s.to_frame().drop_duplicates()
# s.drop(s.index[0:4],inplace=True)
s.rename(columns={0:"ingredients list"},inplace=True)
s
# Out:
#                     ingredients list
#
# c(                                c(
# character(0)            character(0)
# %                                  %
# -inch                          -inch
# ...                              ...
# marinade                    marinade
# remoulade                  remoulade
# sofrito                      sofrito
# fresca                        fresca
# chocolate-covered  chocolate-covered
#
# [1440 rows x 1 columns]

# %%
#splitting keywords to separate columns
keywords = keywords.str.replace(" ", "\"")
temp =keywords.str.split("\"",expand=True)
dummiesk=pd.get_dummies(temp,dtype=int)
dummiesk.columns=dummiesk.columns.str.lower()
sk=dummiesk.columns.str.lstrip('0123456789_').str.lower()
sk=sk.to_frame().drop_duplicates()
# sk.drop(sk.index[0:4],inplace=True)
sk.rename(columns={0:"keywords list"},inplace=True)
sk
# Out:
#         keywords list
#
# c(                 c(
# <                   <
# african       african
# apple           apple
# ...               ...
# wrap             wrap
# contest       contest
# labor           labor
# college       college
# food             food
#
# [304 rows x 1 columns]

# %%
# creating dummy tables for all ingredients
#scanning every column for duplicate named columns
for j in tqdm(range(0,dummies.shape[1])):
    # progress counter
    # if j%100==0:
    #     print(j)
    col_idx_drop=[]

    #merging duplicate columns
    for k in range(j+1,dummies.shape[1]):
        #column duplicate name check
        if (dummies.columns[j].lstrip('0123456789_')==dummies.columns[k].lstrip('0123456789_')):
            #merging duplicate columns
            dummies.iloc[:,j] = dummies.iloc[:,j]+dummies.iloc[:,k]
            col_idx_drop.append(k)
    #dropping the second duplicate named column
    dummies.drop(columns=dummies.columns[col_idx_drop],inplace=True)

for j in range(0,dummies.shape[1]):
    dummies.rename(columns={dummies.columns[j]:dummies.columns[j].lstrip('0123456789_')},inplace=True)
# Out:
#   0%|          | 0/21611 [00:00<?, ?it/s]

# %%
#same rationale applied for keywords, as for ingredients
for j in tqdm(range(0,dummiesk.shape[1])):
    # if j%10000==0:
    #     print(j)
    col_idx_drop=[]
    
    for k in range(j+1,dummiesk.shape[1]):
        if (dummiesk.columns[j].lstrip('0123456789_')==dummiesk.columns[k].lstrip('0123456789_')):
            dummiesk.iloc[:,j] = dummiesk.iloc[:,j]+dummiesk.iloc[:,k]
            col_idx_drop.append(k)
  
    dummiesk.drop(columns=dummiesk.columns[col_idx_drop],inplace=True)

for j in range(0,dummiesk.shape[1]):
    dummiesk.rename(columns={dummiesk.columns[j]:dummiesk.columns[j].lstrip('0123456789_')},inplace=True)
# Out:
#   0%|          | 0/4089 [00:00<?, ?it/s]

# %%
#change to 1 every number greater than 1 on dummy table
dummies[dummies.iloc[:,:]>1]=1
dummiesk[dummiesk.iloc[:,:]>1]=1

#remove columes that are all 1
dummies = dummies.iloc[:,list(dummies.sum()<0.5*len(dummies))]
dummiesk = dummiesk.iloc[:,list(dummiesk.sum()<0.5*len(dummiesk))]

# %%
#create combined table and change the Rating column to int for the ML algorithm
df_combined = pd.concat([df['AggregatedRating'], dummies],axis=1)
df_combined["AggregatedRating"] = df_combined["AggregatedRating"]*2
df_combined.astype(int)
# Out:
#         AggregatedRating  character(0)  %  -inch  absolut  amaretto  amarula  \
# 3800                  10             0  0      0        0         0        0
# 126565                10             0  0      0        0         0        0
# 55151                 10             0  0      0        0         0        0
# 58362                 10             0  0      0        0         0        0
# 123121                10             0  0      0        0         0        0
# ...                  ...           ... ..    ...      ...       ...      ...
# 9                      2             0  0      0        0         0        0
# 275                    2             0  0      0        0         0        0
# 1310                   2             0  0      0        0         0        0
# 417                    2             0  0      0        0         0        0
# 27                     2             0  0      0        0         0        0
#
#         american  bacardi  baker's  ...  barbeque  nan's  dumplings  puerto  \
# 3800           0        0        0  ...         0      0          0       0
# 126565         0        0        0  ...         0      0          0       0
# 55151          0        0        0  ...         0      0          0       0
# 58362          0        0        0  ...         0      0          0       0
# 123121         0        0        0  ...         0      0          0       0
# ...          ...      ...      ...  ...       ...    ...        ...     ...
# 9              0        0        0  ...         0      0          0       0
# 275            0        0        0  ...         0      0          0       0
# 1310           0        0        0  ...         0      0          0       0
# 417            0        0        0  ...         0      0          0       0
# 27             0        0        0  ...         0      0          0       0
#
#         rican  marinade  remoulade  sofrito  fresca  chocolate-covered
# 3800        0         0          0        0       0                  0
# 126565      0         0          0        0       0                  0
# 55151       0         0          0        0       0                  0
# 58362       0         0          0        0       0                  0
# 123121      0         0          0        0       0                  0
# ...       ...       ...        ...      ...     ...                ...
# 9           0         0          0        0       0                  0
# 275         0         0          0        0       0                  0
# 1310        0         0          0        0       0                  0
# 417         0         0          0        0       0                  0
# 27          0         0          0        0       0                  0
#
# [11732 rows x 1435 columns]

# %%
#filter out single rows in df_combined
for x in df_combined["AggregatedRating"].sort_values().unique():
    if len(df_combined[df_combined["AggregatedRating"]==x])==1:
        df_combined.drop(index=df_combined[df_combined["AggregatedRating"]==x].index,inplace=True)

# %%
#export ingredient and keywords file for review
dummies.to_csv('dummies.csv',index=False)
dummiesk.to_csv('dummiesk.csv',index=False)

# %%
df_combined.drop(columns=df_combined.sum().sort_values(ascending=False)[1000:-1].index,inplace=True)
# df_combined.columns=["AggregatedRating", df_combined.sum().sort_values(ascending=False)[:400].index]

# %%
#export df_combined file for review
df_combined.to_csv('df_combined.csv',index=False)

# %%
pd.DataFrame(df_combined.sum()).sort_values(by=0,ascending=False)[:100]
# Out:
#                         0
# AggregatedRating  77096.0
# salt               5032.0
# sugar              4290.0
# butter             3523.0
# pepper             3334.0
# flour              3321.0
# garlic             3052.0
# onion              2803.0
# cheese             2646.0
# water              2472.0
# powder             2440.0
# milk               2256.0
# fresh              2224.0
# ground             2130.0
# oil                2059.0
# eggs               1922.0
# baking             1816.0
# olive              1797.0
# vanilla            1732.0
# cream              1626.0
# chicken            1485.0
# cloves             1444.0
# sauce              1430.0
# black              1418.0
# brown              1413.0
# juice              1365.0
# green              1283.0
# cinnamon           1223.0
# tomatoes           1192.0
# lemon              1180.0
# white              1088.0
# all-purpose        1043.0
# soda                964.0
# parsley             932.0
# dried               896.0
# vinegar             868.0
# beef                808.0
# onions              806.0
# wine                766.0
# broth               764.0
# cheddar             721.0
# extract             695.0
# margarine           679.0
# mustard             673.0
# rice                671.0
# parmesan            670.0
# celery              665.0
# sour                651.0
# potatoes            642.0
# ginger              641.0
# tomato              638.0
# nutmeg              588.0
# cumin               563.0
# basil               562.0
# boneless            561.0
# oregano             545.0
# dry                 543.0
# soy                 537.0
# honey               527.0
# clove               520.0
# bell                514.0
# chili               508.0
# beans               490.0
# skinless            475.0
# thyme               452.0
# leaves              438.0
# whole               434.0
# corn                429.0
# unsalted            429.0
# paprika             429.0
# cornstarch          428.0
# cayenne             421.0
# breasts             417.0
# cilantro            412.0
# carrots             401.0
# light               396.0
# mayonnaise          392.0
# of                  387.0
# worcestershire      386.0
# mushrooms           365.0
# frozen              359.0
# bacon               353.0
# powdered            353.0
# chocolate           341.0
# lime                338.0
# carrot              336.0
# extra               333.0
# heavy               330.0
# walnuts             326.0
# syrup               325.0
# wheat               322.0
# flakes              318.0
# leaf                315.0
# virgin              315.0
# oats                315.0
# paste               313.0
# pasta               310.0
# yellow              299.0
# bay                 298.0
# seeds               297.0

# %%
X.drop(columns=['character(0)', '%', '-inch'],inplace=True)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X=df_combined.drop(columns='AggregatedRating')
y=df_combined['AggregatedRating']

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
classifier = LogisticRegression(solver='liblinear', random_state=1)
classifier.fit(X_train, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.3872030912603705
# Testing Data Score: 0.19604500511421752

# %%
# Predict outcomes for test data set
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).to_csv('del.csv')

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).corr()
# Out:
#             Prediction    Actual
# Prediction    1.000000  0.111981
# Actual        0.111981  1.000000

# %%
y[y==10]
# Out:
# 3800      10.0
# 126565    10.0
# 55151     10.0
# 58362     10.0
# 123121    10.0
#           ...
# 110112    10.0
# 128426    10.0
# 167295    10.0
# 1266      10.0
# 89361     10.0
# Name: AggregatedRating, Length: 1676, dtype: float64

# %%
from sklearn.metrics import accuracy_score
# Display the accuracy score for the test dataset.
accuracy_score(y_test, predictions)
# Out:
# 0.19604500511421752

# %%
# Instantiate the PCA instance and declare the number of PCA variables
pca=PCA(n_components=4)

df_pca = pca.fit_transform(X)

# Review the first 5 rows of the array of list data
# print(df_pca[:5])

# Calculate the PCA explained variance ratio
print(f"PCA variance sum: ({sum(pca.explained_variance_ratio_)}), PCA component variance: ({pca.explained_variance_ratio_})")

# Create the PCA DataFrame
df_pca = pd.DataFrame(
    df_pca
#     # columns=["PCA1", "PCA2", "PCA3"]
)

# # Review the PCA DataFrame
df_pca.head()
# Out:
# PCA variance sum: (0.17837024199925916), PCA component variance: ([0.08147977 0.04332825 0.0283194  0.02524282])
#           0         1         2         3
# 0 -1.334268  0.065195 -0.548216  0.125819
# 1  0.270651 -0.620356 -0.404727 -0.074165
# 2 -0.220613 -0.359697  0.985116 -0.070512
# 3 -0.332150 -0.789470 -0.766643 -0.199943
# 4 -0.434017 -0.528531 -0.627885  0.526688

# %%
# Out:
# 3800      10.0
# 126565    10.0
# 55151     10.0
# 58362     10.0
# 123121    10.0
#           ...
# 9          2.0
# 275        2.0
# 1310       2.0
# 417        2.0
# 27         2.0
# Name: AggregatedRating, Length: 11732, dtype: float64

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
print(f"Model's slope: {model.coef_}")
print(f"Model's y-intercept: {model.intercept_}")
print(f"Model's formula: y = {model.intercept_} + {model.coef_[0]}X")

# Make predictions using the X set
predicted_y_values = pd.DataFrame(model.predict(X), columns=['predicted values'])
# Create a copy of the original data
df_sales_predicted = pd.concat([df_combined['AggregatedRating'].reset_index(),predicted_y_values],axis=1)

# Display sample data
df_sales_predicted.head()
# Out:
# Model's slope: [-3.63790679e-01 -2.77814018e-01  1.10847090e+00 -5.78026138e-01
#   5.75514787e-01  3.09303535e-01  9.37381487e-02  2.75346502e+00
#  -1.63010548e-01 -2.47239579e+00  5.50983398e-01 -1.25160731e+00
#   1.02310876e+00 -1.09710921e+13  1.51233559e-01  2.37647498e+00
#  -1.32872514e-01 -3.34974992e-01  1.30992091e+00  2.45311862e+00
#  -1.39960395e+00  2.29832000e+00  4.50175826e+00  9.96894063e-01
#   7.82694676e-01 -3.66986863e-01 -1.09710921e+13 -2.19200512e-01
#   4.73518043e-01 -3.06756055e+00 -6.83242934e-01  4.40538376e-01
#  -1.37495484e+00  1.66442871e-01 -5.36987305e-01  1.05590820e-02
#   6.82373047e-02  2.16262817e-01 -5.93383789e-01  4.79537964e-01
#   6.86416626e-01 -9.13085938e-02 -4.25048828e-01  6.44531250e-02
#  -1.68112183e+00 -5.40191650e-01 -4.49958801e-01 -9.39277649e-01
#   1.43025416e+13  5.27587891e-01  4.08264160e-01 -4.21112061e-01
#   1.95103455e+00  4.69543457e-01 -1.79119587e-01  8.25729370e-02
#   1.40979004e+00 -6.25854492e-01 -6.68487549e-01  7.03125000e-02
#  -2.26760864e-01 -2.77832031e-01 -5.44433594e-01  4.73632812e-01
#   8.26538086e-01 -3.57910156e-01  3.48449707e-01  5.61523438e-03
#  -1.99066162e-01 -1.44421387e+00  8.16040039e-02  2.94763565e-01
#  -1.13922119e-01  8.49426270e-01 -1.95312500e-01 -4.60449219e-01
#  -2.10294914e+00  2.51434326e-01  3.78417969e-03  4.32373047e-01
#  -1.47146606e+00 -4.50073242e-01  6.26037598e-01 -3.57055664e-02
#   1.98425293e-01  1.05908203e+00 -1.03173065e+00  3.41682434e-01
#  -2.02087402e-01 -1.56158447e-01  1.25803271e+13  9.03320312e-03
#  -4.57678223e+00  2.49490356e+00  2.64824010e+13 -3.61999512e-01
#  -1.40747070e-01 -1.41597748e+00  4.98107910e-01 -2.89978027e-01
#   1.32509995e+00 -1.03759766e-01  3.00292969e-02 -2.17285156e-01
#   1.43130493e+00  1.70534897e+00  6.99462891e-02  8.58154297e-02
#  -1.05514526e+00 -4.06433105e-01 -6.01585388e-01  2.12921143e-01
#  -9.39208984e-01 -7.53295898e-01 -1.85864258e+00  3.32534790e-01
#  -4.08447266e-01  2.28965759e-01  8.32519531e-02 -2.55950928e-01
#  -6.36779785e-01  1.01851654e+00  2.61657715e-01 -3.50708008e-01
#   2.46183014e+00  8.52050781e-02  2.39091492e+00  1.69754028e-01
#   3.40673828e+00 -8.02307129e-01  1.57562256e-01  3.31665039e-01
#  -1.60644531e-01 -1.63787842e-01  5.20782471e-01 -4.68688965e-01
#   9.03320312e-02  1.05387878e+00  5.30700684e-02 -5.25421143e-01
#   4.02832031e-03 -2.82928467e-01  2.99037933e-01 -1.03515625e-01
#   8.49952221e-01  7.87635803e-01  1.02807617e+00  2.82485962e-01
#  -3.18359375e-01  7.77587891e-02  4.53491211e-02  5.31356812e-01
#  -1.28417969e-01 -2.27294922e-01 -8.80126953e-02 -2.49938965e-01
#   3.22967529e-01  1.40697479e+00  6.15887642e-01 -1.79077148e-01
#  -1.38827896e+00  6.79107666e-01 -1.10843658e-01  1.82616234e-01
#   2.75573730e-02 -3.25927734e-02 -3.39031982e+00  1.10745239e+00
#  -6.09436035e-01 -3.91479492e-01 -1.37573242e-01 -3.37867737e-01
#   9.32525635e-01  6.58691406e-01  8.86886597e-01  2.42919922e-02
#   1.15173340e+00  6.88941956e-01 -1.43554688e-01  2.25164795e+00
#   7.27661133e-01 -1.25268555e+00  2.32711792e-01 -9.38476562e-01
#   7.17163086e-02 -1.83471680e-01  7.60284424e-01 -1.49322510e-01
#   1.21276855e-01  7.95898438e-02  4.12414551e-01  9.65652466e-01
#   2.60864258e-01 -3.19854736e-01  9.03320312e-02  5.94177246e-01
#   2.10700989e-01  6.45446777e-02  4.17991638e-01 -3.26232910e-01
#  -1.40777588e+00  8.69140625e-02 -8.02581787e-01  1.61917877e+00
#  -1.06987000e+00  3.48571777e-01 -1.32598877e-01 -7.50213623e-01
#  -7.75024414e-01 -6.73246697e+12 -7.04620361e-01 -2.47192383e-01
#  -1.40441895e-01 -5.20660400e-01  3.89007568e-01 -5.08728027e-02
#  -4.15649414e-01 -3.77517700e-01 -6.79389954e-01  1.21548462e+00
#  -9.42993164e-02  3.62091064e-01  8.90136719e-01  2.19421387e-01
#   8.03222656e-02  7.72705078e-02 -1.44042969e-01  3.75976562e-02
#   2.22106934e-01  9.28176880e-01 -3.39477539e-01 -6.08047485e-01
#  -1.09863281e-01 -7.19390869e-01  1.04077148e+00  1.78222656e-02
#   6.79809570e-01  1.68823242e-01 -4.95330811e-01 -1.07348633e+00
#   1.37771606e+00  1.66595459e-01  9.74397002e+13  1.83410645e-01
#  -3.27178955e-01  1.14196777e+00  6.23779297e-02  2.40806580e+00
#   1.12243652e-01 -1.03275299e+00  1.55700684e-01  3.76953125e-01
#   1.07518005e+00  9.96784925e-01  2.31445312e-01  6.15844727e-01
#  -7.01904297e-04 -3.78723145e-02 -7.69355774e-01 -4.10858154e-01
#   7.29909897e-01 -1.48925781e-02  2.00698853e-01  2.27356911e+00
#  -6.95655823e-01 -1.14746094e-01  1.66931152e-02  1.65194702e+00
#   1.69982910e-01  1.60278320e-01  3.47244263e+00 -4.98779297e-01
#  -6.02493286e-02  5.29785156e-01 -2.63427734e-01 -6.11257553e-01
#   1.11068726e+00  4.61059570e-01  2.08374023e-01 -1.55441284e-01
#   1.58853149e+00  6.44012451e-01  4.07638550e-01 -1.07421875e-01
#   3.66027832e-01  1.99279785e-01  6.70776367e-01 -7.21817017e-01
#   5.38032532e-01  2.16842651e-01 -2.90756226e-01 -4.31442261e-01
#   6.14135742e-01  5.74309349e-01 -4.16336060e-02 -7.64175415e-01
#   1.28392029e+00  8.22753906e-02 -4.35363770e-01 -6.98242188e-02
#  -1.32679367e+00  8.58581543e-01  5.76492310e-01  1.98730469e-01
#   2.06939697e-01 -6.84341431e-01 -2.55737305e-01 -4.47807312e-01
#  -5.53527832e-01  1.35406494e-01 -1.74163818e+00  5.81703186e-01
#  -9.85229492e-01 -8.22158813e-01  2.96417236e-01  1.21005249e+00
#   1.41845703e-01 -1.14746094e-01  6.27349854e-01 -5.85876465e-01
#  -1.24237061e+00  1.38841057e+00 -6.55883789e-01  1.23899841e+00
#  -1.20178223e-01  6.00128174e-02 -6.83395386e-01  6.51855469e-02
#   4.70184326e-01  8.08593750e-01 -7.31231689e-01  2.80123138e+00
#   1.15234566e+00 -1.77093506e-01  2.63671875e-01 -1.86088562e-01
#  -2.34497070e-01  1.95768929e+00  4.22958374e-01 -1.58569336e-01
#   1.15788698e+00  1.37559509e+00 -4.77783203e-01 -1.30615234e-01
#  -5.30946732e-01 -2.96175003e-01  4.66590881e-01  5.28076172e-01
#   2.17895508e-01  4.02660370e-01 -9.38415527e-02  1.70288086e-01
#  -3.14027405e+00  1.66259766e-01  1.80664062e-01  7.96508789e-02
#  -1.34951782e+00 -8.70142937e-01 -5.22888184e-01 -6.16348267e-01
#   8.06617737e-01 -1.65435791e-01  1.42395020e-01  4.89990234e-01
#  -2.69508362e-01  2.37217712e+00  1.72598839e-01  2.15005493e+00
#  -5.53649902e-01 -1.40380859e-02  1.96075439e-01 -1.39526367e-01
#  -1.01860046e+00  9.33807373e-01 -1.09588146e+00  3.71353149e-01
#  -8.68408203e-01 -1.65669733e+13  7.91797638e-01  1.62963867e-02
#   3.84185791e-01  8.38088989e-01 -2.85644531e-02  7.16247559e-02
#   3.05625916e-01 -3.45947266e-01  2.13623047e-02  9.00878906e-02
#   1.26335907e+00  7.72155762e-01  7.03125000e-02  2.25151062e-01
#   1.22949219e+00 -1.07238770e-01 -2.87597656e-01  1.10351562e-01
#   1.70043945e-01  1.33132935e-02 -1.50817871e-01 -5.47332764e-02
#  -1.39855957e+00 -6.13616943e-01  2.80456543e-02 -3.15093994e-02
#  -2.36633301e-01 -9.98535156e-02 -4.53796387e-01  4.37026978e-01
#  -1.50146484e-02 -2.14263916e-01 -1.10168457e-01  2.21150780e+00
#  -1.58468628e+00  4.93011475e-01 -3.71032715e-01 -2.85034180e-01
#  -2.90646362e+00 -1.44396973e+00  4.76730347e-01 -3.22509766e-01
#   2.19482422e-01 -4.43115234e-02 -3.17077637e-01  1.82156372e+00
#   1.82189941e+00  4.80255127e-01 -1.23573303e+00 -7.20214844e-02
#   8.04121017e-01 -2.41943359e-01  3.13720703e-01 -4.22363281e-01
#  -3.86563110e+00  1.96544647e-01  2.88818359e-01 -4.01000977e-02
#  -3.14704895e+00  3.32763672e-01  4.30938721e-01 -4.60815430e-01
#   5.11810303e-01  2.33024597e-01  1.86065674e-01  6.34018183e-01
#   4.80834961e-01 -7.16629028e-02  4.07104492e-01 -1.60034180e-01
#  -3.40042114e-01 -1.92810059e+00 -4.51126099e-01 -9.64813232e-02
#   3.42170715e-01 -7.39913940e-01  7.11212158e-02 -5.12298584e-01
#   3.06518555e-01  2.43057251e-01  5.00488281e-01 -9.82208252e-02
#   5.25512695e-02  1.63772583e-01 -9.22012329e-03 -2.10304260e-01
#  -6.71386719e-03  1.20010376e+00  4.21325684e-01 -2.88085938e-02
#   2.03796387e-01  7.60009766e-01  4.14642334e-01 -5.20812988e-01
#   5.95397949e-01  3.58832151e-01 -8.67889404e-01  8.02425690e+12
#  -3.29833984e-01  4.08966064e-01  5.01586914e-01  3.25439453e-01
#  -6.73246697e+12 -3.52447510e-01 -5.59448242e-01 -1.15536880e+00
#   6.31401062e-01  2.02056885e-01 -1.51977539e-02  2.71270752e-01
#  -1.35009766e-01 -2.08747864e-01  2.38800049e-01 -8.08998108e-01
#  -1.87744141e-01 -6.11877441e-01 -4.25048828e-01  3.96118164e-01
#  -1.27319336e-01 -4.12044525e-01 -2.23388672e-01 -1.81594849e-01
#   9.21859741e-01  1.51985168e-01  3.49334717e-01  2.18585205e+00
#  -2.97698975e+00  1.17495728e+00  2.10723877e-01  8.78906250e-02
#   2.52319336e-01 -3.49819946e+00 -3.00170898e-01 -3.78051758e-01
#   1.27285767e+00  1.23805237e+00 -1.94970703e+00 -4.06112671e-01
#  -1.92683411e+00  1.06945801e+00  5.53405762e-01 -7.44628906e-03
#  -1.06696606e+00  4.14146052e+12 -9.01367188e-01 -6.94134235e-02
#  -1.84936523e-02  7.98797607e-02  3.37707520e-01  1.50146484e-01
#  -2.36985683e+00 -2.14752197e+00  9.29874420e-01 -8.59375000e-02
#  -7.15759277e-01 -9.61502075e-01 -2.60284424e-01 -1.54571533e-02
#   1.32591248e-01 -8.62602234e-01  1.45446777e-01 -6.11026764e-01
#   8.75305176e-01 -2.31201172e-01  1.22223663e+00 -9.33349609e-01
#  -1.04370117e+00  6.03569031e-01  4.71176147e-01  4.29016113e-01
#   1.59400940e+00  1.94520569e+00 -1.73745728e+00  7.00683594e-02
#   1.43798828e-01 -1.29562378e-01  3.56750488e-01 -8.23669434e-02
#   8.91296387e-01 -1.87701847e+13 -1.04241943e+00 -4.63684082e-01
#   9.15191650e-01 -2.73925781e-01 -2.40814209e-01  1.53993225e+00
#   1.32664108e+00  3.44238281e-02  3.36273193e-01  2.80120850e-01
#   9.55631256e-01  3.45916748e-01  4.45556641e-02 -2.14567566e+00
#   2.18650818e-01  4.31060791e-02 -1.61361694e+00  1.45674896e+00
#   1.28662109e-01  1.05029297e+00 -2.26852417e-01 -2.79541016e-01
#   2.23659515e-01 -1.07177734e-01 -2.61138916e-01 -4.43115234e-02
#  -7.54882812e-01  3.10058594e-02  1.30493164e-01  1.54968262e-01
#  -2.56103516e-01  2.19490051e+00  2.32543945e-01 -1.26464844e-01
#  -6.60873413e-01 -3.51440430e-01 -1.49536133e-02  4.39316750e-01
#   1.71595764e+00 -4.14707947e+00  2.71063995e+00 -1.02777100e+00
#  -2.42279053e-01  1.37939453e-02  1.09710921e+13  1.39953613e-01
#   2.70385742e-02  1.01635742e+00 -6.37207031e-02  1.57967377e+00
#  -8.90609741e-01 -4.30206299e-01 -1.09920502e+00 -8.02425690e+12
#   6.96533203e-01  1.65669733e+13  6.55433655e-01 -1.43768311e-01
#   1.40652466e+00 -2.34283447e-01  4.64065552e-01  3.68560791e-01
#   2.14904785e-01 -7.44255066e-01  4.14146052e+12 -1.33290100e+00
#   3.53393555e-01 -5.42297363e-02 -3.16925049e-02 -1.91619873e-01
#  -1.66748047e-01 -1.25803271e+13  2.79113770e-01  1.31915283e+00
#   2.84149170e-01  8.30078125e-02 -4.04251099e-01 -6.15417480e-01
#   4.59751129e-01  2.98225403e-01 -2.04325867e+00 -6.86340332e-01
#  -4.67056274e-01 -4.48364258e-01 -4.14146052e+12 -1.65487671e+00
#   4.89624023e-01 -8.45718384e-01 -1.47399902e-02 -1.23544502e+00
#  -3.93035889e-01  4.61395264e-01 -2.38838196e+00  1.87194824e-01
#  -3.41522217e-01  2.46520996e-01 -1.86344910e+00 -4.76135254e-01
#  -8.62491608e-01  1.83471680e-01  5.85998535e-01 -6.94519043e-01
#   4.23034668e-01  4.88464355e+00  2.09238434e+00 -1.32088470e+00
#   2.68310547e-01 -1.40603638e+00  1.15520477e+00 -8.65844727e-01
#  -4.79202271e-01 -1.43025416e+13 -6.70471191e-01 -4.96610260e+00
#   4.27604675e-01  2.67166138e-01  5.08003235e-01  8.88977051e-02
#  -1.25488281e-01 -9.57855225e-01  2.36267090e-01  2.78076172e-01
#  -1.41995239e+00 -1.30349731e+00  8.15611601e-01  2.55187988e-01
#   6.07334137e-01 -3.20007324e-01  1.11663818e+00  3.70651245e-01
#  -7.30194092e-01 -2.18429565e-01 -1.70926285e+00 -6.59759521e-01
#  -3.15520859e+00 -3.35876465e-01  6.46484375e-01  8.94348145e-01
#   3.94219637e-01 -2.19238281e-01 -1.24451447e+00 -2.52090454e-01
#  -3.87573242e-01 -4.26818848e-01 -8.92944336e-01 -1.68212891e-01
#   6.31103516e-02 -5.72723389e-01 -1.46069336e+00  5.61969757e-01
#   5.90538025e-01  2.04113770e+00  2.05665588e+00  1.65283203e-01
#  -1.98425293e-01  1.36104584e+00 -2.00064850e+00  1.27239990e+00
#   6.73246697e+12 -7.29400635e-01 -1.69372559e-01 -6.52313232e-02
#  -1.17492676e-02  6.73246697e+12 -4.07226562e-01 -2.88085938e-02
#  -1.56376648e+00  1.87701847e+13 -7.85766602e-01 -1.08123779e-01
#   2.38078308e+00  1.41907501e+00  4.15649414e-01  9.20776367e-01
#  -6.12792969e-01 -9.74397002e+13  1.54815674e-01  2.33886719e-01
#  -1.10168457e+00 -2.47395325e+00  2.37709045e+00 -1.93603516e-01
#   5.75920105e-01  9.86236572e-01 -1.61606598e+00 -1.16952515e+00
#   7.89520264e-01  8.07495117e-01 -1.90643311e-01  7.31903076e-01
#  -2.33032227e-01  5.20431519e-01  1.72723389e+00 -1.04638672e+00
#  -3.67919922e-01 -1.36108398e-01 -3.94226074e-01 -9.44690704e-02
#  -7.33911514e-01  2.55058670e+00 -2.61367798e-01  4.21936035e-01
#   1.03149414e-01 -5.21484375e-01  7.55233765e-02 -2.64824010e+13
#  -3.93524170e-02 -3.83972168e-01  2.37213135e-01  3.14727783e-01
#   1.10534668e-01 -4.18273926e-01 -2.58666992e-01  6.15844727e-01
#  -9.03228760e-01  4.13146973e-01 -1.78955078e-01  1.00674438e+00
#  -9.87152100e-01 -9.58057404e-01  1.60339355e+00  3.71200562e-01
#   1.83242798e-01  2.07144165e+00  1.87127686e+00 -3.13858032e-01
#  -1.64609909e-01  1.89334869e+00  3.08166504e-01  3.28994751e-01
#   4.94812012e-01 -5.82458496e-01 -4.74548340e-03  9.01550293e-01
#   1.73126221e-01 -6.58264160e-01  1.60488129e-01  5.58502197e-01
#   4.92534637e-02  1.08477402e+00  1.21463776e+00 -1.74346924e+00
#   2.36343341e+11  1.68111610e+00 -1.85173941e+00 -2.78915405e-01
#  -2.38038826e+00  1.69887543e+00  7.36129761e-01  2.12661743e+00
#  -2.78526306e-01 -1.17601013e+00  1.78332520e+00 -1.05648994e-01
#  -4.22645569e-01  3.82415771e-01  1.72543335e+00  4.68154907e-01
#  -4.56970215e-01 -1.40676880e+00  1.67126465e+00  3.76167297e-01
#  -8.28155518e-01 -1.14723206e-01 -1.05285645e-01 -1.91650391e-01
#  -2.35168457e+00  8.89587402e-01 -8.74856949e-01 -1.55659485e+00
#  -1.27452929e+13  1.12335205e+00 -1.00982666e+00  6.73317581e-01
#   1.12335205e-01 -7.74459839e-01  2.18883324e+00 -6.93664551e-01
#   9.14318085e-01 -3.68932724e-01  7.16766357e-01 -9.09324646e-01
#   4.85961914e-01  1.29444520e+13  1.06259452e+12  1.16265106e+00
#   9.10644531e-01 -5.34362793e-02  7.42309570e-01 -4.24453341e+12
#   1.65274048e+00 -4.18029785e-01  2.53747559e+00  1.21966457e+00
#  -1.67370605e+00 -2.73181915e-01 -4.26586914e+00  6.14467621e-01
#  -5.25588989e-01  2.13273621e+00 -2.92001534e+00 -2.39495913e+11
#  -1.08212280e+00 -4.21340942e-01 -1.85219955e+00 -3.05318832e-02
#  -2.70378113e-01  1.27452929e+13  5.08544922e-01  2.43544769e+00
#  -2.16064453e-02  7.68890381e-02 -3.04464340e-01  6.73246697e+12
#   5.52932739e-01 -3.72009277e-02 -4.78668213e-01  7.56622314e-01
#  -1.71173096e+00  7.10021973e-01 -9.05574799e-01 -5.73242188e-01
#   2.66969299e+00 -1.06259452e+12 -3.81936646e+00  4.81529236e-01
#  -9.52789307e-01  5.61764526e+00  2.39495913e+11 -2.29175568e+00
#   6.16455078e-03  8.97994995e-01  1.18591309e+00  4.37576294e-01
#   8.08189392e-01 -2.36343341e+11 -2.74308777e+00  2.28967667e-01
#   4.24453341e+12 -1.44973755e+00 -3.38439941e-02 -7.84555435e-01
#  -1.29444520e+13  1.89369202e+00 -2.84638977e+00  5.80596924e-01
#   1.81122303e-01 -2.59872437e-01 -3.36090088e-01 -4.26452637e-01
#  -2.36448288e-01 -3.69228363e-01 -1.35185242e+00 -9.83551025e-01
#  -1.67846680e-02  1.67890930e+00 -5.77806473e-01 -1.07891846e+00
#   9.17984009e-01 -4.73934937e+00 -2.19786072e+00  1.03881836e-01
#   2.00363159e+00 -1.30355835e+00 -1.97573853e+00  3.73840332e-01
#   9.73030090e-01  1.10256958e+00 -1.34778976e+00 -2.04161072e+00
#   1.25318909e+00  1.64871979e+00  1.39892578e+00 -2.66907883e+00
#  -4.10583496e-01 -2.86934280e+00 -1.21399879e-01 -8.87947083e-01
#  -9.97047424e-01  1.80313110e-01  3.18359375e-01  1.11428833e+00
#   2.96356201e-01 -2.71155548e+00  1.37687683e+00  2.52795410e+00
#  -2.92648315e+00  1.84048462e+00  2.48564148e+00 -1.26626015e-01
#  -5.44937134e-01  1.43502808e+00  2.25856781e+00  4.59564209e-01
#   2.28951263e+00  7.53372192e-01  1.63256836e+00 -1.97290039e+00
#   9.71321106e-01  1.90788269e+00 -2.13317108e+00 -1.13485718e+00
#  -1.66854858e+00 -1.37142944e+00  5.84783554e-02 -5.46546936e-01
#  -4.14651489e+00  8.40766907e-01 -6.34403229e-02  1.69436264e+00
#   5.49139023e-01  1.15274048e+00 -2.83622742e+00  5.11810303e-01
#  -7.52483368e-01 -1.47302880e+12 -1.90768433e+00  3.67050171e-01
#   1.47302880e+12  1.25110626e+00  4.34753418e-01 -3.17629910e+00
#   1.63577652e+00  1.00190735e+00 -1.45080468e+12  1.13867188e+00
#   1.78848267e-01  1.45080468e+12  1.71384811e-01 -8.14056396e-01
#  -1.85006714e+00 -8.74588966e-01  2.86514282e+00  3.10211182e-02
#  -2.08074951e+00  4.24453341e+12  6.23360634e-01  4.42434692e+00]
# Model's y-intercept: 6.453752790178571
# Model's formula: y = 6.453752790178571 + -0.36379067850087393X
#     index  AggregatedRating  predicted values
# 0    3800              10.0          5.291308
# 1  126565              10.0          7.118647
# 2   55151              10.0          6.898493
# 3   58362              10.0          7.275433
# 4  123121              10.0          6.547350

# %%
print(X.shape, model.coef_.shape)
pd.DataFrame([X.columns, model.coef_, X.sum()]).T.to_csv('weight.csv')
# Out:
# (11732, 996) (996,)

# %%
X.sum()
# Out:
# character(0)         44
# %                    72
# -inch                 9
# amaretto             24
# american             34
#                      ..
# hickory               3
# stout                 5
# shoot                 4
# bechamel              3
# chocolate-covered     1
# Length: 996, dtype: int64

# %%
model.coef_.shape
# Out:
# (996,)

# %%
df_sales_predicted.to_csv('result.csv')

# %%
# df_sales_predicted.drop(columns=['index'],inplace=True)
df_sales_predicted.dropna(inplace=True)
df_sales_predicted.drop(index=df_sales_predicted[df_sales_predicted['predicted values']<-100].index,inplace=True)
df_sales_predicted.drop(index=df_sales_predicted[df_sales_predicted['predicted values']>100].index,inplace=True)
df_sales_predicted
# Out:
#        index  AggregatedRating  predicted values
# 0       3800              10.0          7.609804
# 1     126565              10.0          6.733847
# 2      55151              10.0          7.375422
# 3      58362              10.0          6.531863
# 4     123121              10.0          7.501757
# ...      ...               ...               ...
# 8794    2020               4.0          7.137728
# 8795     963               4.0          6.224512
# 8796    1100               4.0          4.861094
# 8797    1837               4.0          5.146731
# 8798    1951               4.0          6.915435
#
# [8482 rows x 3 columns]

# %%
df_sales_predicted['AggregatedRating'].unique()
# Out:
# array([10.,  8.,  9.,  6.,  7.,  4.])

# %%
import matplotlib.pyplot as plt
# j=0
# data=[]
# for i in df_sales_predicted['AggregatedRating'].unique():
#     data[j]=pd.concat([data, df_sales_predicted[df_sales_predicted['AggregatedRating']==i]['predicted values']],axis=0)
#     j+=1

plt.violinplot([df_sales_predicted[df_sales_predicted['AggregatedRating']==2]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==4]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==6]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==7]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==8]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==9]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==10]['predicted values']], positions=[2, 4, 6, 7, 8, 9, 10])
plt.boxplot([df_sales_predicted[df_sales_predicted['AggregatedRating']==2]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==4]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==6]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==7]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==8]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==9]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==10]['predicted values']], positions=[2, 4, 6, 7, 8, 9, 10],
            flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.scatter(df_sales_predicted['AggregatedRating']+0.2*random.rand(len(df_sales_predicted['AggregatedRating']),1).ravel()-.1,
            df_sales_predicted['predicted values'],marker='o',s=.01,c='r')
plt.xlabel("AggregatedRating")
plt.ylabel("predicted values")
plt.title('Test values using full X sample')
plt.show()

# %%
from numpy import random

random.rand(len(df_sales_predicted['AggregatedRating']),1)
# Out:
# array([[0.47894295],
#        [0.76290316],
#        [0.41381329],
#        ...,
#        [0.3729936 ],
#        [0.9180169 ],
#        [0.41542136]])

# %%
df_sales_predicted['AggregatedRating']
random.rand(len(df_sales_predicted['AggregatedRating']),1).ravel().reshape(-1,1)
# Out:
# array([[0.33389611],
#        [0.44823512],
#        [0.82526998],
#        ...,
#        [0.10904758],
#        [0.92051898],
#        [0.02101675]])

# %%
plt.violinplot([df_sales_predicted[df_sales_predicted['AggregatedRating']==8]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==10]['predicted values']], positions=[8, 10])
plt.boxplot([df_sales_predicted[df_sales_predicted['AggregatedRating']==8]['predicted values'],
            df_sales_predicted[df_sales_predicted['AggregatedRating']==10]['predicted values']],  positions=[8, 10],
            flierprops={'marker': 'o', 'markersize': 0, 'markeredgecolor': 'red'} )
plt.xlabel("AggregatedRating")
plt.ylabel("predicted values")
plt.scatter(df_sales_predicted['AggregatedRating']+0.2*random.rand(len(df_sales_predicted['AggregatedRating']),1).ravel()-.1,
            df_sales_predicted['predicted values'],marker='o',s=.11,c='r')
plt.title('Test values using training sample')
plt.show()

# %%
df_sales_predicted[df_sales_predicted['AggregatedRating']==10]['predicted values']
# Out:
# 0       5.258085
# 1       7.109828
# 2       6.892204
# 3       7.292039
# 4       6.537104
#           ...
# 1671    5.000378
# 1672    8.586219
# 1673    6.110495
# 1674    7.036670
# 1675    8.570919
# Name: predicted values, Length: 1676, dtype: float64

# %% [markdown]
# ## Dimensionality reduction
